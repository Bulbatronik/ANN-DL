# %% [markdown]
# # Initialization

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
plt.rc('font', size=16)

import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
# Enable/disable test mode
test_mode = True

# %% [markdown]
# ## Import and visualize the dataset

# %%
# Set the path to the dataset
dataset = pd.read_csv('../input/homework2/Training.csv')
#dataset = pd.read_csv('../input/Training.csv')
print(dataset.shape) 
dataset.head().transpose()
# Out:
# (68528, 7)
#                            0          1         2          3          4
# Sponginess           7.97698   8.078240   8.02844   8.028440   7.875720
# Wonder level         4.33494   4.446160   4.22372   4.223720   4.446160
# Crunchiness         10.67282  10.561600  10.56160  10.561600  10.450380
# Loudness on impact   1.76692   1.707160   1.64906   1.707160   1.707160
# Meme creativity      3.22440   3.325660   3.17460   3.174600   3.275860
# Soap slipperiness   51.68146  51.563598  50.86308  45.841581  47.126421
# Hype root            3.65434   3.476720   3.47672   3.476720   3.476720

# %%
dataset.head()
# Out:
#    Sponginess  Wonder level  Crunchiness  Loudness on impact  Meme creativity  \
# 0     7.97698       4.33494     10.67282             1.76692          3.22440
# 1     8.07824       4.44616     10.56160             1.70716          3.32566
# 2     8.02844       4.22372     10.56160             1.64906          3.17460
# 3     8.02844       4.22372     10.56160             1.70716          3.17460
# 4     7.87572       4.44616     10.45038             1.70716          3.27586
#
#    Soap slipperiness  Hype root
# 0          51.681460    3.65434
# 1          51.563598    3.47672
# 2          50.863080    3.47672
# 3          45.841581    3.47672
# 4          47.126421    3.47672

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68528 entries, 0 to 68527
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sponginess          68528 non-null  float64
#  1   Wonder level        68528 non-null  float64
#  2   Crunchiness         68528 non-null  float64
#  3   Loudness on impact  68528 non-null  float64
#  4   Meme creativity     68528 non-null  float64
#  5   Soap slipperiness   68528 non-null  float64
#  6   Hype root           68528 non-null  float64
# dtypes: float64(7)
# memory usage: 3.7 MB

# %%
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
inspect_dataframe(dataset, dataset.columns)

# %% [markdown]
# # Data preprocessing

# %%
if(test_mode):
    test_size = 10000
    X_train_raw = dataset.iloc[:-test_size]
    X_test_raw = dataset.iloc[-test_size:]
else:
    X_train_raw = dataset

# y_train_raw = y.iloc[:-test_size]
# Normalize both features and labels
X_min = X_train_raw.min()
X_max = X_train_raw.max()

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)

if(test_mode):
    # y_test_raw = y.iloc[-test_size:]
    X_test_raw = (X_test_raw-X_min)/(X_max-X_min)

# %% [markdown]
# ## Extracting sequences from the dataset

# %%
def build_sequences(df, target_labels, window, stride, telescope):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float32')#float32
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float32')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
target_labels = dataset.columns
window = 200
stride = 5
telescope = 1

# %%
future = dataset[-window:]
future = (future-X_min)/(X_max-X_min)
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 200, 7)

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)
print(X_train.shape, y_train.shape)

if(test_mode):
    X_test, y_test = build_sequences(X_test_raw, target_labels, window, stride, telescope)
    print(X_test.shape, y_test.shape)
# Out:
# (11680, 200, 7) (11680, 1, 7)
# (1960, 200, 7) (1960, 1, 7)

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate(X_train, y_train, target_labels, telescope)

# %% [markdown]
# # Train the model

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
print(y_train.shape)

batch_size = 128
epochs = 200

model_name = 'seq2seq'
# Out:
# (11680, 1, 7)

# %%
def build_model(input_shape ,output_shape):
    #create model
    model = tfk.Sequential()

    input_train = tfk.Input(shape=input_shape)

    # encoder, 3 lstm layers
    enc_stack_h, enc_last_h, enc_last_c, x, y = tfkl.Bidirectional(tfkl.LSTM(units=256, return_sequences=True, return_state=True))(input_train)
    enc_stack_h, enc_last_h, enc_last_c, x, y = tfkl.Bidirectional(tfkl.LSTM(units=256, return_sequences=True, return_state=True))(enc_stack_h, initial_state=[enc_last_h, enc_last_c, x, y])
    enc_stack_h, enc_last_h, enc_last_c, x, y = tfkl.Bidirectional(tfkl.LSTM(units=256, return_sequences=True, return_state=True))(enc_stack_h, initial_state=[enc_last_h, enc_last_c, x, y])

    # decoder
    dec_input = tfkl.RepeatVector(output_shape[0])(enc_last_h)
    dec_stack_h, dec_last_h, dec_last_c, x, y = tfkl.Bidirectional(tfkl.LSTM(units=256, return_sequences=True, return_state=True))(dec_input, initial_state=[enc_last_h, enc_last_c, x, y])
    dec_stack_h = tfkl.Bidirectional(tfkl.LSTM(units=256, return_sequences=True, return_state=False))(dec_stack_h, initial_state=[dec_last_h, dec_last_c, x, y])

    # attention
    attention = tfkl.dot([dec_stack_h, enc_stack_h], axes=[2, 2])
    attention = tfkl.Activation('softmax')(attention)

    ## context
    context = tfkl.dot([attention, enc_stack_h], axes=[2, 1])
    dec_combined = tfkl.concatenate([context, dec_stack_h])

    # output
    out = tfkl.TimeDistributed(tfkl.Dense(units=output_shape[1]))(dec_combined)

    model = tfk.Model(inputs=input_train, outputs=out)
    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae'])


    return model

# %%
model = build_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# 2022-01-13 13:15:04.716111: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:15:04.853607: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:15:04.854365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:15:04.856198: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-13 13:15:04.857480: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:15:04.858449: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:15:04.859315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:15:07.452099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:15:07.453002: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:15:07.453726: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:15:07.454353: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 7)]     0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   [(None, 200, 512), ( 540672      input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) [(None, 200, 512), ( 1574912     bidirectional[0][0]
#                                                                  bidirectional[0][1]
#                                                                  bidirectional[0][2]
#                                                                  bidirectional[0][3]
#                                                                  bidirectional[0][4]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) [(None, 200, 512), ( 1574912     bidirectional_1[0][0]
#                                                                  bidirectional_1[0][1]
#                                                                  bidirectional_1[0][2]
#                                                                  bidirectional_1[0][3]
#                                                                  bidirectional_1[0][4]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 1, 256)       0           bidirectional_2[0][1]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) [(None, 1, 512), (No 1050624     repeat_vector[0][0]
#                                                                  bidirectional_2[0][1]
#                                                                  bidirectional_2[0][2]
#                                                                  bidirectional_2[0][3]
#                                                                  bidirectional_2[0][4]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 1, 512)       1574912     bidirectional_3[0][0]
#                                                                  bidirectional_3[0][1]
#                                                                  bidirectional_3[0][2]
#                                                                  bidirectional_3[0][3]
#                                                                  bidirectional_3[0][4]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1, 200)       0           bidirectional_4[0][0]
#                                                                  bidirectional_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 200)       0           dot[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1, 512)       0           activation[0][0]
#                                                                  bidirectional_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 1024)      0           dot_1[0][0]
#                                                                  bidirectional_4[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 1, 7)         7175        concatenate[0][0]
# ==================================================================================================
# Total params: 6,323,207
# Trainable params: 6,323,207
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.2,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# 2022-01-13 13:15:11.127074: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-01-13 13:15:19.140186: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla P100-PCIE-16GB" frequency: 1328 num_cores: 56 environment { key: "architecture" value: "6.0" } environment { key: "cuda" value: "11000" } environment { key: "cudnn" value: "8005" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 16152002560 bandwidth: 732160000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-01-13 13:15:20.759751: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 73/73 [==============================] - ETA: 0s - loss: 0.0133 - mae: 0.0723
# 2022-01-13 13:15:40.448288: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla P100-PCIE-16GB" frequency: 1328 num_cores: 56 environment { key: "architecture" value: "6.0" } environment { key: "cuda" value: "11000" } environment { key: "cudnn" value: "8005" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 16152002560 bandwidth: 732160000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 73/73 [==============================] - 31s 269ms/step - loss: 0.0133 - mae: 0.0723 - val_loss: 0.0032 - val_mae: 0.0401
# Epoch 2/200
# 73/73 [==============================] - 16s 225ms/step - loss: 0.0023 - mae: 0.0358 - val_loss: 0.0019 - val_mae: 0.0325
# Epoch 3/200
# 73/73 [==============================] - 16s 225ms/step - loss: 0.0016 - mae: 0.0294 - val_loss: 0.0015 - val_mae: 0.0275
# Epoch 4/200
# 73/73 [==============================] - 16s 225ms/step - loss: 0.0014 - mae: 0.0266 - val_loss: 0.0013 - val_mae: 0.0256
# Epoch 5/200
200
# 73/73 [==============================] - 16s 225ms/step - loss: 7.4242e-04 - mae: 0.0174 - val_loss: 7.4686e-04 - val_mae: 0.0175
# Epoch 53/200
# 73/73 [==============================] - 16s 224ms/step - loss: 7.4307e-04 - mae: 0.0174 - val_loss: 7.4857e-04 - val_mae: 0.0176
# Epoch 54/200
# 73/73 [==============================] - 16s 225ms/step - loss: 7.4184e-04 - mae: 0.0174 - val_loss: 7.5423e-04 - val_mae: 0.0176
# Epoch 55/200
# 73/73 [==============================] - 16s 224ms/step - loss: 7.4340e-04 - mae: 0.0174 - val_loss: 7.4466e-04 - val_mae: 0.0175
# Epoch 56/200
# 73/73 [==============================] - 16s 225ms/step - loss: 7.4327e-04 - mae: 0.0174 - val_loss: 7.5578e-04 - val_mae: 0.0178
# Epoch 57/200
# 73/73 [==============================] - 16s 224ms/step - loss: 7.4128e-04 - mae: 0.0174 - val_loss: 7.4558e-04 - val_mae: 0.0176

# %%
exp_dir = ''
model.save(os.path.join(exp_dir, model_name))
# Out:
# 2022-01-13 13:31:22.037760: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %% [markdown]
# # Analyze the results

# %%
# Plot loss, accuracy and learning rate
best_epoch = np.argmin(history['val_loss'])

plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set 
if(test_mode):
    predictions = model.predict(X_test)
    print(predictions.shape)

    mean_squared_error = tfk.metrics.mse(y_test.flatten(),predictions.flatten())
    mean_absolute_error = tfk.metrics.mae(y_test.flatten(),predictions.flatten())
    print(mean_squared_error, mean_absolute_error)
# Out:
# 2022-01-13 13:32:01.866041: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla P100-PCIE-16GB" frequency: 1328 num_cores: 56 environment { key: "architecture" value: "6.0" } environment { key: "cuda" value: "11000" } environment { key: "cudnn" value: "8005" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 16152002560 bandwidth: 732160000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# (1960, 1, 7)
# tf.Tensor(0.0012398171, shape=(), dtype=float32) tf.Tensor(0.022506561, shape=(), dtype=float32)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
if(test_mode):
    inspect_multivariate_prediction(X_test, y_test, predictions, target_labels, telescope)

# %%
if(test_mode):
    reg_telescope = 216 # 864/4, 864 is too high
    X_test_reg, y_test_reg = build_sequences(X_test_raw, target_labels, window, stride, reg_telescope)
    print(X_test_reg.shape, y_test_reg.shape)

    # Autoregressive Forecasting
    reg_predictions = np.array([])
    X_temp = X_test_reg
    for reg in range(0,reg_telescope,telescope):
        pred_temp = model.predict(X_temp)
        if(len(reg_predictions)==0):
            reg_predictions = pred_temp
        else:
            reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)
# Out:
# (1917, 200, 7) (1917, 216, 7)

# %%
if(test_mode):
    print(reg_predictions.shape)
# Out:
# (1917, 216, 7)

# %%
if(test_mode):
    mean_squared_error = tfk.metrics.mse(y_test_reg.flatten(),reg_predictions.flatten())
    mean_absolute_error = tfk.metrics.mae(y_test_reg.flatten(),reg_predictions.flatten())
    print(mean_squared_error, mean_absolute_error)
# Out:
# tf.Tensor(0.012734421, shape=(), dtype=float32) tf.Tensor(0.075331256, shape=(), dtype=float32)

# %%
if(test_mode):
    inspect_multivariate_prediction(X_test_reg, y_test_reg, reg_predictions, target_labels, reg_telescope)

# %%
if(test_mode):
    maes = []
    for i in range(predictions.shape[1]):
        ft_maes = []
        for j in range(predictions.shape[2]):
            ft_maes.append(np.mean(np.abs(y_test[:,i,j]-predictions[:,i,j]), axis=0))
        ft_maes = np.array(ft_maes)
        maes.append(ft_maes)
    maes = np.array(maes)
    print(maes)
# Out:
# [[0.02378545 0.02681539 0.02581494 0.027139   0.02077057 0.00647516
#   0.02674541]]

# %%
if(test_mode):
    future_predictions = model.predict(future)
    print(future_predictions.shape)
# Out:
# (1, 1, 7)

# %%
if(test_mode):
    figs, axs = plt.subplots(len(target_labels), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(target_labels):
        axs[i].plot(np.arange(len(future[0,:,i])), future[0,:,i])
        axs[i].plot(np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), future_predictions[0,:,i], color='orange')
        axs[i].fill_between(
            np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), 
            future_predictions[0,:,i]+maes[:,i], 
            future_predictions[0,:,i]-maes[:,i], 
            color='orange', alpha=.3)
        axs[i].set_title(col)
        # axs[i].set_ylim(0,1)
    plt.show()
