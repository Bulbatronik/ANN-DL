# %% [markdown]
# # Initialization

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
plt.rc('font', size=16)

import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
# Enable/disable test mode
test_mode = True

# %% [markdown]
# ## Import and visualize the dataset

# %%
# Set the path to the dataset
dataset = pd.read_csv('../input/homework2/Training.csv')
#dataset = pd.read_csv('../input/Training.csv')
print(dataset.shape) 
dataset.head().transpose()
# Out:
# (68528, 7)
#                            0          1         2          3          4
# Sponginess           7.97698   8.078240   8.02844   8.028440   7.875720
# Wonder level         4.33494   4.446160   4.22372   4.223720   4.446160
# Crunchiness         10.67282  10.561600  10.56160  10.561600  10.450380
# Loudness on impact   1.76692   1.707160   1.64906   1.707160   1.707160
# Meme creativity      3.22440   3.325660   3.17460   3.174600   3.275860
# Soap slipperiness   51.68146  51.563598  50.86308  45.841581  47.126421
# Hype root            3.65434   3.476720   3.47672   3.476720   3.476720

# %%
dataset.head()
# Out:
#    Sponginess  Wonder level  Crunchiness  Loudness on impact  Meme creativity  \
# 0     7.97698       4.33494     10.67282             1.76692          3.22440
# 1     8.07824       4.44616     10.56160             1.70716          3.32566
# 2     8.02844       4.22372     10.56160             1.64906          3.17460
# 3     8.02844       4.22372     10.56160             1.70716          3.17460
# 4     7.87572       4.44616     10.45038             1.70716          3.27586
#
#    Soap slipperiness  Hype root
# 0          51.681460    3.65434
# 1          51.563598    3.47672
# 2          50.863080    3.47672
# 3          45.841581    3.47672
# 4          47.126421    3.47672

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68528 entries, 0 to 68527
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sponginess          68528 non-null  float64
#  1   Wonder level        68528 non-null  float64
#  2   Crunchiness         68528 non-null  float64
#  3   Loudness on impact  68528 non-null  float64
#  4   Meme creativity     68528 non-null  float64
#  5   Soap slipperiness   68528 non-null  float64
#  6   Hype root           68528 non-null  float64
# dtypes: float64(7)
# memory usage: 3.7 MB

# %%
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
inspect_dataframe(dataset, dataset.columns)

# %% [markdown]
# # Data preprocessing

# %%
if(test_mode):
    test_size = 10000
    X_train_raw = dataset.iloc[:-test_size]
    X_test_raw = dataset.iloc[-test_size:]
else:
    X_train_raw = dataset

# y_train_raw = y.iloc[:-test_size]
# Normalize both features and labels
X_min = X_train_raw.min()
X_max = X_train_raw.max()

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)

if(test_mode):
    # y_test_raw = y.iloc[-test_size:]
    X_test_raw = (X_test_raw-X_min)/(X_max-X_min)

# %% [markdown]
# ## Extracting sequences from the dataset

# %%
def build_sequences(df, target_labels, window, stride, telescope):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float32')#float32
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float32')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
target_labels = dataset.columns
window = 200
stride = 5
telescope = 1

# %%
future = dataset[-window:]
future = (future-X_min)/(X_max-X_min)
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 200, 7)

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)
print(X_train.shape, y_train.shape)

if(test_mode):
    X_test, y_test = build_sequences(X_test_raw, target_labels, window, stride, telescope)
    print(X_test.shape, y_test.shape)
# Out:
# (11680, 200, 7) (11680, 1, 7)
# (1960, 200, 7) (1960, 1, 7)

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate(X_train, y_train, target_labels, telescope)

# %% [markdown]
# # Train the model

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
print(y_train.shape)

batch_size = 128
epochs = 200

model_name = 'seq2seq'
# Out:
# (11680, 1, 7)

# %%
def build_model(input_shape ,output_shape):
    #create model
    model = tfk.Sequential()

    # encoder
    model.add(tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True), input_shape=input_shape))
    model.add(tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True)))
    model.add(tfkl.Bidirectional(tfkl.LSTM(256)))

    # feature vector
    model.add(tfkl.RepeatVector(output_shape[0]))

    # decoder
    model.add(tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True)))
    model.add(tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True)))
    model.add(tfkl.TimeDistributed(tfkl.Dense(output_shape[1])))

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae'])


    return model

# %%
model = build_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# 2022-01-08 11:33:07.655786: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 11:33:07.751422: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 11:33:07.752162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 11:33:07.753376: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-08 11:33:07.754415: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 11:33:07.755065: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 11:33:07.755731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 11:33:09.560772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 11:33:09.561674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 11:33:09.562313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 11:33:09.562879: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 200, 512)          540672
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 200, 512)          1574912
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 512)               1574912
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 512)            0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 1, 512)            1574912
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 1, 512)            1574912
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 7)              3591
# =================================================================
# Total params: 6,843,911
# Trainable params: 6,843,911
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.15,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# 2022-01-08 11:33:13.396219: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-01-08 11:33:24.502829: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 78/78 [==============================] - 31s 241ms/step - loss: 0.0311 - mae: 0.1273 - val_loss: 0.0226 - val_mae: 0.1081
# Epoch 2/200
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0188 - mae: 0.1031 - val_loss: 0.0186 - val_mae: 0.1097
# Epoch 3/200
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0133 - mae: 0.0869 - val_loss: 0.0145 - val_mae: 0.0997
# Epoch 4/200
# 78/78 [==============================] - 16s 209ms/step - loss: 0.0102 - mae: 0.0739 - val_loss: 0.0106 - val_mae: 0.0836
# Epoch 5/200
# 78/78 [==============================] - 16s 209ms/step - loss: 0.0062 - mae: 0.0571 - val_loss: 0.0059 - val_mae: 0.0546
# Epoch 6/200
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0030 - mae: 0.0392 - val_loss: 0.0026 - val_mae: 0.0365
# Epoch 7/200
# 78/78 [==============================] - 16s 209ms/step - loss: 0.0019 - mae: 0.0321 - val_loss: 0.0033 - val_mae: 0.0455
# Epoch 8/200
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0015 - mae: 0.0282 - val_loss: 0.0015 - val_mae: 0.0283
# Epoch 9/200
# 78/78 [==============================] - 16s 209ms/step - loss: 0.0014 - mae: 0.0266 - val_loss: 0.0012 - val_mae: 0.0247
# Epoch 10/200
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 0.0012 - val_mae: 0.0257
# Epoch 11/200
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0017 - val_mae: 0.0310
# Epoch 12/200
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0017 - val_mae: 0.0307
# Epoch 13/200
# 78/78 [==============================] - 16s 210ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0010 - val_mae: 0.0217
# Epoch 14/200
# 78/78 [==============================] - 16s 210ms/step - loss: 9.6391e-04 - mae: 0.0214 - val_loss: 0.0010 - val_mae: 0.0229
# Epoch 15/200
# 78/78 [==============================] - 16s 210ms/step - loss: 9.6584e-04 - mae: 0.0215 - val_loss: 0.0011 - val_mae: 0.0234
# Epoch 16/200
# 78/78 [==============================] - 16s 209ms/step - loss: 9.7689e-04 - mae: 0.0219 - val_loss: 0.0014 - val_mae: 0.0280
# Epoch 17/200
# 78/78 [==============================] - 16s 209ms/step - loss: 0.0010 - mae: 0.0223 - val_loss: 0.0012 - val_mae: 0.0260
# Epoch 18/200
# 78/78 [==============================] - 16s 209ms/step - loss: 0.0011 - mae: 0.0230 - val_loss: 9.6225e-04 - val_mae: 0.0220
# Epoch 19/200
# 78/78 [==============================] - 16s 209ms/step - loss: 8.4736e-04 - mae: 0.0195 - val_loss: 0.0011 - val_mae: 0.0241
# Epoch 20/200
# 78/78 [==============================] - 16s 210ms/step - loss: 8.4130e-04 - mae: 0.0194 - val_loss: 8.9880e-04 - val_mae: 0.0203
# Epoch 21/200
# 78/78 [==============================] - 16s 208ms/step - loss: 8.3517e-04 - mae: 0.0192 - val_loss: 0.0011 - val_mae: 0.0233
# Epoch 22/200
# 78/78 [==============================] - 16s 209ms/step - loss: 8.2487e-04 - mae: 0.0192 - val_loss: 8.2772e-04 - val_mae: 0.0190
# Epoch 23/200
# 78/78 [==============================] - 16s 209ms/step - loss: 8.4646e-04 - mae: 0.0195 - val_loss: 8.3264e-04 - val_mae: 0.0188
# Epoch 24/200
# 78/78 [==============================] - 16s 209ms/step - loss: 8.2508e-04 - mae: 0.0192 - val_loss: 8.4905e-04 - val_mae: 0.0197
# Epoch 25/200
# 78/78 [==============================] - 16s 210ms/step - loss: 8.1618e-04 - mae: 0.0190 - val_loss: 9.3059e-04 - val_mae: 0.0204
# Epoch 26/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.7559e-04 - mae: 0.0182 - val_loss: 8.4451e-04 - val_mae: 0.0191
# Epoch 27/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.8265e-04 - mae: 0.0183 - val_loss: 8.0625e-04 - val_mae: 0.0185
# Epoch 28/200
# 78/78 [==============================] - 16s 210ms/step - loss: 7.7729e-04 - mae: 0.0182 - val_loss: 9.1133e-04 - val_mae: 0.0201
# Epoch 29/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.8022e-04 - mae: 0.0183 - val_loss: 8.4327e-04 - val_mae: 0.0193
# Epoch 30/200
# 78/78 [==============================] - 16s 210ms/step - loss: 7.6740e-04 - mae: 0.0180 - val_loss: 8.2082e-04 - val_mae: 0.0188
# Epoch 31/200
# 78/78 [==============================] - 16s 211ms/step - loss: 7.5063e-04 - mae: 0.0176 - val_loss: 8.1441e-04 - val_mae: 0.0186
# Epoch 32/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.5472e-04 - mae: 0.0177 - val_loss: 8.6411e-04 - val_mae: 0.0195
# Epoch 33/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.5852e-04 - mae: 0.0178 - val_loss: 8.1746e-04 - val_mae: 0.0188
# Epoch 34/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.5143e-04 - mae: 0.0176 - val_loss: 8.3596e-04 - val_mae: 0.0193
# Epoch 35/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.4725e-04 - mae: 0.0176 - val_loss: 7.9495e-04 - val_mae: 0.0185
# Epoch 36/200
# 78/78 [==============================] - 16s 210ms/step - loss: 7.5077e-04 - mae: 0.0177 - val_loss: 8.1067e-04 - val_mae: 0.0187
# Epoch 37/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.4566e-04 - mae: 0.0176 - val_loss: 8.5340e-04 - val_mae: 0.0194
# Epoch 38/200
# 78/78 [==============================] - 16s 210ms/step - loss: 7.4171e-04 - mae: 0.0175 - val_loss: 8.2579e-04 - val_mae: 0.0191
# Epoch 39/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.5755e-04 - mae: 0.0179 - val_loss: 8.7953e-04 - val_mae: 0.0199
# Epoch 40/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.5576e-04 - mae: 0.0178 - val_loss: 8.2032e-04 - val_mae: 0.0190
# Epoch 41/200
# 78/78 [==============================] - 16s 207ms/step - loss: 7.3615e-04 - mae: 0.0174 - val_loss: 8.3280e-04 - val_mae: 0.0191
# Epoch 42/200
# 78/78 [==============================] - 16s 207ms/step - loss: 7.3757e-04 - mae: 0.0174 - val_loss: 7.9152e-04 - val_mae: 0.0183
# Epoch 43/200
# 78/78 [==============================] - 16s 207ms/step - loss: 7.3414e-04 - mae: 0.0174 - val_loss: 8.3287e-04 - val_mae: 0.0192
# Epoch 44/200
# 78/78 [==============================] - 16s 207ms/step - loss: 7.3009e-04 - mae: 0.0173 - val_loss: 7.9160e-04 - val_mae: 0.0183
# Epoch 45/200
# 78/78 [==============================] - 16s 207ms/step - loss: 7.3349e-04 - mae: 0.0174 - val_loss: 7.8216e-04 - val_mae: 0.0181
# Epoch 46/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.2401e-04 - mae: 0.0172 - val_loss: 8.0051e-04 - val_mae: 0.0183
# Epoch 47/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.2505e-04 - mae: 0.0172 - val_loss: 8.0263e-04 - val_mae: 0.0184
# Epoch 48/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.2559e-04 - mae: 0.0172 - val_loss: 7.9353e-04 - val_mae: 0.0184
# Epoch 49/200
# 78/78 [==============================] - 16s 207ms/step - loss: 7.2332e-04 - mae: 0.0172 - val_loss: 7.7661e-04 - val_mae: 0.0181
# Epoch 50/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.2427e-04 - mae: 0.0172 - val_loss: 7.7533e-04 - val_mae: 0.0181
# Epoch 51/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.2165e-04 - mae: 0.0171 - val_loss: 8.0637e-04 - val_mae: 0.0186
# Epoch 52/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.2013e-04 - mae: 0.0171 - val_loss: 7.9884e-04 - val_mae: 0.0185
# Epoch 53/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.1933e-04 - mae: 0.0171 - val_loss: 7.7058e-04 - val_mae: 0.0179
# Epoch 54/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.2191e-04 - mae: 0.0171 - val_loss: 8.0339e-04 - val_mae: 0.0186
# Epoch 55/200
# 78/78 [==============================] - 16s 207ms/step - loss: 7.1986e-04 - mae: 0.0171 - val_loss: 7.7458e-04 - val_mae: 0.0180
# Epoch 56/200
# 78/78 [==============================] - 16s 207ms/step - loss: 7.1946e-04 - mae: 0.0171 - val_loss: 7.9291e-04 - val_mae: 0.0185
# Epoch 57/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.1824e-04 - mae: 0.0171 - val_loss: 7.8525e-04 - val_mae: 0.0182
# Epoch 58/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.1824e-04 - mae: 0.0171 - val_loss: 7.9670e-04 - val_mae: 0.0184
# Epoch 59/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.1870e-04 - mae: 0.0171 - val_loss: 7.8849e-04 - val_mae: 0.0182
# Epoch 60/200
# 78/78 [==============================] - 16s 208ms/step - loss: 7.1739e-04 - mae: 0.0171 - val_loss: 7.9197e-04 - val_mae: 0.0184
# Epoch 61/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.1786e-04 - mae: 0.0171 - val_loss: 7.8032e-04 - val_mae: 0.0182
# Epoch 62/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.1763e-04 - mae: 0.0171 - val_loss: 7.8007e-04 - val_mae: 0.0182
# Epoch 63/200
# 78/78 [==============================] - 16s 209ms/step - loss: 7.1747e-04 - mae: 0.0171 - val_loss: 7.7084e-04 - val_mae: 0.0180

# %%
exp_dir = ''
model.save(os.path.join(exp_dir, model_name))
# Out:
# 2022-01-08 11:50:56.685509: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %% [markdown]
# # Analyze the results

# %%
# Plot loss, accuracy and learning rate
best_epoch = np.argmin(history['val_loss'])

plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set 
if(test_mode):
    predictions = model.predict(X_test)
    print(predictions.shape)

    mean_squared_error = tfk.metrics.mse(y_test.flatten(),predictions.flatten())
    mean_absolute_error = tfk.metrics.mae(y_test.flatten(),predictions.flatten())
    print(mean_squared_error, mean_absolute_error)
# Out:
# (1960, 1, 7)
# tf.Tensor(0.0012239716, shape=(), dtype=float32) tf.Tensor(0.022201786, shape=(), dtype=float32)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
if(test_mode):
    inspect_multivariate_prediction(X_test, y_test, predictions, target_labels, telescope)

# %%
if(test_mode):
    reg_telescope = 216 # 864/4, 864 is too high
    X_test_reg, y_test_reg = build_sequences(X_test_raw, target_labels, window, stride, reg_telescope)
    print(X_test_reg.shape, y_test_reg.shape)

    # Autoregressive Forecasting
    reg_predictions = np.array([])
    X_temp = X_test_reg
    for reg in range(0,reg_telescope,telescope):
        pred_temp = model.predict(X_temp)
        if(len(reg_predictions)==0):
            reg_predictions = pred_temp
        else:
            reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)
# Out:
# (1917, 200, 7) (1917, 216, 7)

# %%
if(test_mode):
    print(reg_predictions.shape)
# Out:
# (1917, 216, 7)

# %%
if(test_mode):
    mean_squared_error = tfk.metrics.mse(y_test_reg.flatten(),reg_predictions.flatten())
    mean_absolute_error = tfk.metrics.mae(y_test_reg.flatten(),reg_predictions.flatten())
    print(mean_squared_error, mean_absolute_error)
# Out:
# tf.Tensor(0.015064496, shape=(), dtype=float32) tf.Tensor(0.08978567, shape=(), dtype=float32)

# %%
if(test_mode):
    inspect_multivariate_prediction(X_test_reg, y_test_reg, reg_predictions, target_labels, reg_telescope)

# %%
if(test_mode):
    maes = []
    for i in range(predictions.shape[1]):
        ft_maes = []
        for j in range(predictions.shape[2]):
            ft_maes.append(np.mean(np.abs(y_test[:,i,j]-predictions[:,i,j]), axis=0))
        ft_maes = np.array(ft_maes)
        maes.append(ft_maes)
    maes = np.array(maes)

# %%
if(test_mode):
    future_predictions = model.predict(future)
    print(future_predictions.shape)
# Out:
# (1, 1, 7)

# %%
if(test_mode):
    figs, axs = plt.subplots(len(target_labels), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(target_labels):
        axs[i].plot(np.arange(len(future[0,:,i])), future[0,:,i])
        axs[i].plot(np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), future_predictions[0,:,i], color='orange')
        axs[i].fill_between(
            np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), 
            future_predictions[0,:,i]+maes[:,i], 
            future_predictions[0,:,i]-maes[:,i], 
            color='orange', alpha=.3)
        axs[i].set_title(col)
        # axs[i].set_ylim(0,1)
    plt.show()
